# %%
# Importar librería para la conexión con MySQL
# -----------------------------------------------------------------------
import mysql.connector
from mysql.connector import errorcode


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# %%
import requests
import re
pd.set_option('display.max_columns', None)

# %%
#FUNCION PARA PASAR CSV A LISTA DE TUPLAS

import math
action= pd.read_csv("Comedy.csv")
# for i in comedy:
#     print(i)

lista_de_tuplas = list(action.itertuples(index=False, name=None))
lista_de_tuplas

# ## funcion para cuando de problemas de float en vez de enteros

def to_int_if_possible(value):
     if isinstance(value, float) and math.isnan(value):
         return value
     try:
         return int(value)
     except (ValueError, TypeError):
        return value

# # # Convertir los elementos 2 y 3 de cada tupla
lista_de_tuplas_modificada = [(tupla[0], tupla[1], to_int_if_possible(tupla[2]), to_int_if_possible(tupla[3]), tupla[4], tupla[5])
  for tupla in lista_de_tuplas
 ]

print(lista_de_tuplas_modificada)
# Out:
# [('Movie', 'This Wretched Life', 7, 2010, 'tt0331312', 'Comedy'), ('Movie', 'Blind Sided', nan, nan, 'tt0337882', 'Comedy'), ('Movie', "Anderson's Cross", 5, 2010, 'tt0393049', 'Comedy'), ('Movie', 'Rapunzel', 12, 2010, 'tt0398286', 'Comedy'), ('Movie', 'Venus & Vegas', 11, 2010, 'tt0423474', 'Comedy'), ('Movie', 'Dinner for Schmucks', 8, 2010, 'tt0427152', 'Comedy'), ('Movie', 'Toy Story 3', 6, 2010, 'tt0435761', 'Comedy'), ('Movie', 'Diary of a Bad Lad', 2, 2010, 'tt0449005', 'Comedy'), ('Movie', 'Scott Pilgrim vs. the World', 11, 2010, 'tt0446029', 'Comedy'), ('Movie', 'El hada buena - Una fábula peronista', 4, 2010, 'tt0454155', 'Comedy'), ('Movie', 'Guns, Drugs and Dirty Money', nan, 2011, 'tt0464032', 'Comedy'), ('Movie', 'Piranha 3D', 9, 2010, 'tt0464154', 'Comedy'), ('Movie', 'Harlem Hostel', 2, 2010, 'tt0469094', 'Comedy'), ('Movie', 'Stiffs', nan, 2010, 'tt0476023', 'Comedy'), ('Movie', 'Barry Munday', 3, 2010, 'tt0482461', 'Comedy'), ('Movie', 'A Woman Is a Woman', nan, 2010, 'tt0483839', 'Comedy'), ('Movie', 'PrimeMates', 1, 2010, 'tt0490199', 'Comedy'), ('Movie', 'Ramona and Beezus', 7, 2010, 'tt0493949', 'Comedy'), ('Movie', 'Furry Vengeance', 7, 2010, 'tt0492389', 'Comedy'), ('Movie', 'Love & Other Drugs', 1, 2011, 'tt0758752', 'Comedy'), ('Movie', 'Waste of Space', 4, 2010, 'tt0765485', 'Comedy'), ('Movie', 'The Guardians', nan, 2010, 'tt0800054', 'Comedy'), ('Movie', "It's Kind of a Funny Story", 10, 2010, 'tt0804497', 'Comedy'), ('Movie', 'Tooth Fairy', 1, 2010, 'tt0808510', 'Comedy'), ('Movie', 'Plumíferos - Aventuras voladoras', 2, 2010, 'tt0811021', 'Comedy'), ('Movie', "She's Out of My League", 6, 2010, 'tt0815236', 'Comedy'), ('Movie', "Valentine's Day", 2, 2010, 'tt0817230', 'Comedy'), ('Movie', 'Flipped', 9, 2010, 'tt0817177', 'Comedy'), ('Movie', 'Return to Yucca Flats: Desert Man-Beast', 1, 2010, 'tt0826532', 'Comedy'), ('Movie', 'The Kids Are All Right', 12, 2010, 'tt0842926', 'Comedy'), ('Movie', 'Gangster Exchange', 2, 2010, 'tt0846004', 'Comedy'), ('Movie', 'Fauj Mein Mauj', nan, 2010, 'tt0847735', 'Comedy'), ('Movie', '2001 Maniacs: Field of Screams', 2, 2010, 'tt0858411', 'Comedy'), ('Movie', 'Wide Blue Yonder', 5, 2012, 'tt0858500', 'Comedy'), ('Movie', 'Zenitram', 5, 2010, 'tt0861747', 'Comedy'), ('Movie', 'Touch Wood', nan, nan, 'tt0870208', 'Comedy'), ('Movie', 'Please Give', 7, 2010, 'tt0878835', 'Comedy'), ('Movie', 'AIR: The Musical', 4, 2010, 'tt0882741', 'Comedy'), ('Movie', 'Repo', nan, 2010, 'tt0887161', 'Comedy'), ('Movie', 'The Switch', 10, 2010, 'tt0889573', 'Comedy'), ('Movie', 'Letters to Juliet', 6, 2010, 'tt0892318', 'Comedy'), ('Movie', 'Shrek Forever After', 7, 2010, 'tt0892791', 'Comedy'), ('Movie', 'How to Train Your Dragon', 3, 2010, 'tt0892769', 'Comedy'), ('Movie', "Movin' In", 8, 2010, 'tt0910926', 'Comedy'), ('Movie', 'Jackboots on Whitehall', 10, 2010, 'tt0915463', 'Comedy'), ('Movie', 'De gelukkige huisvrouw', 4, 2010, 'tt0920459', 'Comedy'), ('Movie', 'Pizza with Bullets', nan, 2021, 'tt0924266', 'Comedy'), ('Movie', 'The Penthouse', 3, 2010, 'tt0929618', 'Comedy'), ('Movie', 'Private Security Officer: Los Angeles', 12, 2010, 'tt0960827', 'Comedy'), ('Movie', 'Made in Romania', nan, 2010, 'tt0963177', 'Comedy'), ('Movie', "Pushin' Up Daisies", 6, 2010, 'tt0964544', 'Comedy'), ('Movie', "L'imbroglio nel lenzuolo", 6, 2010, 'tt0965429', 'Comedy'), ('Movie', 'The Chosen One', 9, 2010, 'tt0970926', 'Comedy'), ('Movie', 'Little Fockers', 12, 2010, 'tt0970866', 'Comedy'), ('Movie', 'Lottery Ticket', 8, 2010, 'tt0979434', 'Comedy'), ('Movie', 'Multiple Sarcasms', 4, 2010, 'tt0984210', 'Comedy'), ('Movie', 'Adventure Scouts', 10, 2010, 'tt0994917', 'Comedy'), ('Short', 'Mundo de locos', 1, 2010, 'tt10010264', 'Comedy'), ('Movie', 'Megamind', 12, 2010, 'tt1001526', 'Comedy'), ('Movie', 'The Rum Diary', 12, 2011, 'tt0376136', 'Comedy'), ('Movie', 'Gnomeo & Juliet', 2, 2011, 'tt0377981', 'Comedy'), ('Movie', 'Seven Fallen Objects', 5, 2011, 'tt0407194', 'Comedy'), ('Movie', ' ...

# %%
## VERSION FASE 1

import mysql.connector

# Conectarse a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='proyecto2')

mycursor = cnx.cursor()

# SQL para insertar datos en la tabla peliculas
sql = "INSERT INTO datos_fase1 (Tipo, Nombre, Mes, Año, id_pelicula, Genero) VALUES (%s, %s, %s, %s, %s, %s)"

# Datos a insertar
val1 = lista_de_tuplas_modificada

# Contador de registros insertados
registros_insertados = 0

# creamos bucle para iterar sobre los registros de manera individual, si encuentra el error 1062 lo omite y si encuentra otro para para avisarnos
for registro in val1:
    try:
        mycursor.execute(sql, registro)
        cnx.commit()
        registros_insertados += 1
    except mysql.connector.Error as err:
        if err.errno == 1062:
            # Error de duplicado, omitir y continuar
            print(f"Error: Registro duplicado {registro}. Omitiendo este registro.")
        else:
            # Otro error, mostrar y parar
            print(f"Error: {err}")
            break

print(f"{registros_insertados} registro/s insertado/s.")

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()
# Out:
# Error: Registro duplicado ('Movie', 'This Wretched Life', 7, 2010, 'tt0331312', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Blind Sided', nan, nan, 'tt0337882', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "Anderson's Cross", 5, 2010, 'tt0393049', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Rapunzel', 12, 2010, 'tt0398286', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Venus & Vegas', 11, 2010, 'tt0423474', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Dinner for Schmucks', 8, 2010, 'tt0427152', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Toy Story 3', 6, 2010, 'tt0435761', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Diary of a Bad Lad', 2, 2010, 'tt0449005', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Scott Pilgrim vs. the World', 11, 2010, 'tt0446029', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'El hada buena - Una fábula peronista', 4, 2010, 'tt0454155', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Guns, Drugs and Dirty Money', nan, 2011, 'tt0464032', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Piranha 3D', 9, 2010, 'tt0464154', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Harlem Hostel', 2, 2010, 'tt0469094', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Stiffs', nan, 2010, 'tt0476023', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Barry Munday', 3, 2010, 'tt0482461', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'A Woman Is a Woman', nan, 2010, 'tt0483839', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'PrimeMates', 1, 2010, 'tt0490199', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Ramona and Beezus', 7, 2010, 'tt0493949', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Furry Vengeance', 7, 2010, 'tt0492389', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Love & Other Drugs', 1, 2011, 'tt0758752', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Waste of Space', 4, 2010, 'tt0765485', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Guardians', nan, 2010, 'tt0800054', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "It's Kind of a Funny Story", 10, 2010, 'tt0804497', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Tooth Fairy', 1, 2010, 'tt0808510', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Plumíferos - Aventuras voladoras', 2, 2010, 'tt0811021', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "She's Out of My League", 6, 2010, 'tt0815236', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Rum Diary', 12, 2011, 'tt0376136', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Gnomeo & Juliet', 2, 2011, 'tt0377981', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Seven Fallen Objects', 5, 2011, 'tt0407194', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Satin', 3, 2011, 'tt0433397', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Puss in Boots', 12, 2011, 'tt0448694', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Generation P', 4, 2011, 'tt0459748', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Salvando al Soldado Pérez', 3, 2011, 'tt0461336', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Silent Alarm', 1, 2011, 'tt0462536', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Act Your Age', 4, 2011, 'tt0464891', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Smurfs', 8, 2011, 'tt0472181', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Stan', nan, 2011, 'tt0473088', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Tower Heist', 11, 2011, 'tt0471042', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Bamboo Shark', nan, 2012, 'tt0473122', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Hall Pass', 3, 2011, 'tt0480687', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Monkey Man', 1, 2011, 'tt0483740', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'La daga de Rasputín', 1, 2011, 'tt0484828', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Something Borrowed', 6, 2011, 'tt0491152', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "What's Your Number?", 10, 2011, 'tt0770703', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Till You Get to Baraboo', nan, nan, 'tt0770819', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Kill', 9, 2011, 'tt0772179', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Red Dog', 8, 2011, 'tt0803061', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Jack and Jill', 2, 2012, 'tt0810913', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Take Me Home Tonight', 3, 2011, 'tt0810922', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Hoodwinked Too! Hood vs. Evil', 7, 2011, 'tt0844993', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Pox', 4, 2011, 'tt0844915', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Loot', 11, 2011, 'tt0847180', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Naked Run', 5, 2011, 'tt0852986', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Foodfight!', 2, 2013, 'tt0249516', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "Life's a Beach", 5, 2012, 'tt0285252', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Three Stooges', 4, 2012, 'tt0383010', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Gambit', 6, 2013, 'tt0404978', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Acorralados', 6, 2012, 'tt0426566', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Os Penetras', 11, 2012, 'tt0452664', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Persona Au Gratin', 8, 2012, 'tt0475360', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Sushi in Suhl', 10, 2012, 'tt0485521', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'A Thousand Words', 3, 2012, 'tt0763831', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Escape from Planet Earth', 11, 2014, 'tt0765446', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Elliot Loves', 5, 2012, 'tt0790653', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Do-Deca-Pentathlon', 10, 2015, 'tt0811137', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Babymakers', 6, 2013, 'tt0835418', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Hotel Transylvania', 12, 2012, 'tt0837562', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Whatever Happened to Pete Blaggit?', 3, 2012, 'tt0841185', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Sir Billi', 4, 2012, 'tt0851471', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Nightclub Days', nan, nan, 'tt0871891', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Jewtopia', 11, 2013, 'tt0878814', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Freaky Deaky', 4, 2012, 'tt0938305', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Trouble with Cali', 2, 2012, 'tt0961755', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Significant Other', 12, 2012, 'tt0991173', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Return to Babylon', 8, 2013, 'tt0255820', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Secret Life of Walter Mitty', 1, 2014, 'tt0359950', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Blunt Movie', 4, 2013, 'tt0452183', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Alan Partridge: Alpha Papa', 8, 2013, 'tt0469021', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Croods', 3, 2013, 'tt0481499', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Aftermath', 3, 2013, 'tt0490075', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Syrup', 5, 2013, 'tt0762138', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Santorini Blue', 5, 2013, 'tt0780625', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Incredible Burt Wonderstone', 3, 2013, 'tt0790628', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'R.I.P.D.', 10, 2013, 'tt0790736', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Scary Movie 5', 5, 2013, 'tt0795461', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'La mula', 5, 2013, 'tt0804509', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Wolf of Wall Street', 1, 2014, 'tt0993846', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Frivolinas', 10, 2014, 'tt0016906', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'The Fresh Lobster', 9, 2014, 'tt0168809', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Rice Girl', 7, 2014, 'tt0329539', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Before We Go', 11, 2020, 'tt0443465', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'A Long Way Down', 3, 2014, 'tt0458413', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Kid Cannabis', 7, 2014, 'tt0780548', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Boxtrolls', 10, 2014, 'tt0787474', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Rupan sansei', 8, 2014, 'tt0862748', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Mr. Peabody & Sherman', 2, 2014, 'tt0864835', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Hamlet A.D.D.', 4, 2014, 'tt0892062', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'A Merry Christmas Miracle', 11, 2014, 'tt0910885', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Out of Sight', 11, 2014, 'tt0959306', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Extendables', 8, 2014, 'tt0996664', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Tracy Smith: La Cueva de Resurrección', 1, 2014, 'tt10014526', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Transeúntes', 4, 2015, 'tt0346045', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Prozac tango', 11, 2015, 'tt0420097', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Ant-Man', 7, 2015, 'tt0478970', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Wedding Ringer', 3, 2015, 'tt0884732', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Publicité SAAQ - campagne publicitaire sur les drogues au volant (Pigeon)', 4, 2015, 'tt10005306', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'The Sexlife of a Chair', 10, 2016, 'tt0357159', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Cowboys: Outrage!', 10, 2016, 'tt0359111', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', "Cowboys: That's Nothin'", 10, 2016, 'tt0359113', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Cowboys: The Conformist', 10, 2016, 'tt0359114', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'The Ten Commandments Number 5: Thou Shalt Not Kill', 10, 2016, 'tt0373361', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Nonkina tosan Yamazaki kaido', 11, 2016, 'tt0422842', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Career Day', nan, nan, 'tt0461165', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Hail, Caesar!', 2, 2016, 'tt0475290', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Have You Seen Me?', nan, 2016, 'tt0765453', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Manhattan Minutiae', 5, 2016, 'tt0821486', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Maximum Ride', 8, 2016, 'tt0825283', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "Pee-wee's Big Holiday", 3, 2016, 'tt0837156', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Retreat!', 8, 2016, 'tt0838194', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "The Unlikely's", nan, nan, 'tt0906327', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Quan jia fu', 10, 2017, 'tt0087963', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'La telenovela errante', 9, 2018, 'tt0100275', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Joe Finds Grace', 4, 2017, 'tt0137204', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Bunyan and Babe', 1, 2017, 'tt0331314', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Suburbicon', 11, 2017, 'tt0491175', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'CHIPS', 3, 2017, 'tt0493405', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Caravaggio and My Mother the Pope', 12, 2017, 'tt0825334', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Krystal', 4, 2018, 'tt0835802', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Joe Dick', 1, 2017, 'tt0937225', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'A Thin Life', 1, 2018, 'tt0111414', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Nappily Ever After', 9, 2018, 'tt0365545', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Super Troopers 2', 4, 2018, 'tt0859635', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Shazam!', 4, 2019, 'tt0448115', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Dirt', 3, 2019, 'tt0800325', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Surviving in L.A.', 8, 2020, 'tt0446792', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Witches', 11, 2020, 'tt0805647', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Jak najdalej stad', 8, 2021, 'tt10004368', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Paranoia Tapes: URBAN LEGEND', 2, 2020, 'tt10005078', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'The Last Queen on Earth', 8, 2020, 'tt10005772', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Like.Share.Repost.', 4, 2020, 'tt10011184', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Daily Bus', nan, 2020, 'tt10014322', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'The International Style', 3, 2021, 'tt0195838', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Oak, Ivy, and Other Dead Elms', 3, 2021, 'tt0195957', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "'77", 5, 2007, 'tt0326716', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Jungle Cruise', 7, 2021, 'tt0870154', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'F-Word', 3, 2021, 'tt10010852', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The 10th Man', 7, 2021, 'tt10010874', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'If I Only had a Name', 2, 2021, 'tt10020060', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'La metafísica del asesino', 9, 2021, 'tt10024902', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'One Moment', 3, 2021, 'tt10037934', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Welcome to Mumbai', 3, 2021, 'tt10040326', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'A Trip with Your Wife', 2, 2021, 'tt10044946', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Generation Wrecks', 9, 2021, 'tt10042868', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Engaged in Vegas', 5, 2021, 'tt10043660', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'The Nod', 5, 2021, 'tt10046798', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Bad President', 9, 2021, 'tt10047958', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Supercool', 2, 2022, 'tt10055546', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Let Me Be Frank', 9, 2021, 'tt10068716', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Il materiale emotivo', 10, 2021, 'tt10072662', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Bole Chudiyan', nan, 2021, 'tt10083868', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Bhoot Police', 9, 2021, 'tt10083640', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "I Won't Be Home for Christmas", 12, 2021, 'tt10095332', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Roohi', 4, 2021, 'tt10098288', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'My Little Pony: Een nieuwe generatie', 9, 2021, 'tt10101702', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Happy Thanksgiving', 11, 2021, 'tt10111198', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Way It Is and the Way It Used to Be', 12, 2021, 'tt10116556', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Milli Vanilli', nan, 2022, 'tt0965381', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Laal Singh Chaddha', 8, 2022, 'tt10028196', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'MobSense', nan, 2022, 'tt10029484', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Adventures in Game Chasing', 1, 2022, 'tt10035194', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Christmas Spirit', nan, 2022, 'tt10047464', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Sneakerella', 5, 2022, 'tt10160886', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Gap Weekend', 9, 2022, 'tt10193142', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Bernice, Too', 2, 2022, 'tt10215442', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Wyjdź za mnie', 2, 2022, 'tt10223460', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Stroke of Luck', 1, 2022, 'tt10234990', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Stalking Elvis', 3, 2022, 'tt10257354', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Find Your Horn & Let It Kill You', 7, 2022, 'tt10288194', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Strange World', 11, 2022, 'tt10298840', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Amsterdam', 10, 2022, 'tt10304142', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Short', 'Toxicos', 11, 2022, 'tt10303920', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Big Gold Brick', 8, 2022, 'tt10308878', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Unplugging', 1, 2023, 'tt10314040', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Levi Roots', nan, nan, 'tt10321490', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "Slugger O'Toole", 3, 2022, 'tt10345880', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "Fisherman's Friends: One and All", 11, 2022, 'tt10373344', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Jayeshbhai Jordaar', 5, 2022, 'tt10393870', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "L'homme parfait", 6, 2022, 'tt10415020', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Honest to God', 5, 2022, 'tt10430844', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Shazam! Fury of the Gods', 3, 2023, 'tt10151854', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Rapture Camp', 5, 2023, 'tt10178004', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "Creepers 'R Us", 9, 2023, 'tt10305228', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Bad Boy', 4, 2023, 'tt10351180', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Miraculous: Filmen om Ladybug & Cat Noir', 7, 2023, 'tt10364034', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Os Perebas', 11, 2023, 'tt10750578', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Next Goal Wins', 1, 2024, 'tt10767052', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Al Reves', 2, 2023, 'tt10810852', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Ant-Man and the Wasp: Quantumania', 2, 2023, 'tt10954600', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Reception', 6, 2023, 'tt11170966', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'De Vuelta Al Mundo', 4, 2023, 'tt11241232', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'The Out-Laws', 7, 2023, 'tt11274492', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Wish', 11, 2023, 'tt11304740', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Pizzodyssey', 2, 2024, 'tt10408218', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'IF', 5, 2024, 'tt11152168', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Staycation', 9, 2024, 'tt12975102', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Broken Glass', 2, 2024, 'tt13036100', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Hitpig', nan, 2024, 'tt13176330', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Food Fight', 2, 2024, 'tt13311746', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', 'Moana 2', 11, 2024, 'tt13622970', 'Comedy'). Omitiendo este registro.
# Error: Registro duplicado ('Movie', "We Don't Say Retard Anymore", 9, 2024, 'tt13695406', 'Comedy'). Omitiendo este registro.
# 179 registro/s insertado/s.

# %%
## VERSION FASE 2

import mysql.connector

# Conectarse a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='proyecto2')

mycursor = cnx.cursor()

# SQL para insertar datos en la tabla peliculas
sql = "INSERT INTO datos_fase2 (id_pelicula,puntuacion_imdb,Argumento,Titulo_Pelicula,Directores,Guionistas,Duracion_Peli,Puntuacion_Tomatoes) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"

# Datos a insertar
val1 = lista_de_tuplas

# Contador de registros insertados
registros_insertados = 0

# creamos bucle para iterar sobre los registros de manera individual, si encuentra el error 1062 lo omite y si encuentra otro para para avisarnos
for registro in val1:
    try:
        mycursor.execute(sql, registro)
        cnx.commit()
        registros_insertados += 1
    except mysql.connector.Error as err:
        if err.errno == 1062:
            # Error de duplicado, omitir y continuar
            print(f"Error: Registro duplicado {registro}. Omitiendo este registro.")
        else:
            # Otro error, mostrar y parar
            print(f"Error: {err}")
            break

print(f"{registros_insertados} registro/s insertado/s.")

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()
# Out:
# Error: Registro duplicado ('tt0331312', 7.8, 'Awakening from a near fatal overdose, Chris embraces a second chance at life. Required to enroll into a 12-Step Program, and mandated to state psychiatrist appointments, Chris is forced to r... Read all', 'This Wretched Life', 'Frankie J. Mosca', 'Frankie J. MoscaSal DeLuciaAnde Cira', '1h 39m', nan). Omitiendo este registro.
# 9 registro/s insertado/s.

# %%
## VERSION FASE ACTORES

import mysql.connector

# Conectarse a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='proyecto2')

mycursor = cnx.cursor()

# SQL para insertar datos en la tabla peliculas
sql = "INSERT INTO  () VALUES (%s, %s, %s, %s, %s, %s)"

# Datos a insertar
val1 = 

# Contador de registros insertados
registros_insertados = 0

# creamos bucle para iterar sobre los registros de manera individual, si encuentra el error 1062 lo omite y si encuentra otro para para avisarnos
for registro in val1:
    try:
        mycursor.execute(sql, registro)
        cnx.commit()
        registros_insertados += 1
    except mysql.connector.Error as err:
        if err.errno == 1062:
            # Error de duplicado, omitir y continuar
            print(f"Error: Registro duplicado {registro}. Omitiendo este registro.")
        else:
            # Otro error, mostrar y parar
            print(f"Error: {err}")
            break

print(f"{registros_insertados} registro/s insertado/s.")

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()

# %%
## VERSION FASE OSCARS

import mysql.connector

# Conectarse a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='proyecto2')

mycursor = cnx.cursor()

# SQL para insertar datos en la tabla peliculas
sql = "INSERT INTO  () VALUES (%s, %s, %s, %s, %s, %s)"

# Datos a insertar
val1 = 

# Contador de registros insertados
registros_insertados = 0

# creamos bucle para iterar sobre los registros de manera individual, si encuentra el error 1062 lo omite y si encuentra otro para para avisarnos
for registro in val1:
    try:
        mycursor.execute(sql, registro)
        cnx.commit()
        registros_insertados += 1
    except mysql.connector.Error as err:
        if err.errno == 1062:
            # Error de duplicado, omitir y continuar
            print(f"Error: Registro duplicado {registro}. Omitiendo este registro.")
        else:
            # Otro error, mostrar y parar
            print(f"Error: {err}")
            break

print(f"{registros_insertados} registro/s insertado/s.")

# Cerrar el cursor y la conexión
mycursor.close()
cnx.close()

# %%
# VERSION CON VARIOS VALORES - no usar ahora


import mysql.connector

# Conectarse a la base de datos
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1', database='proyecto2')

mycursor = cnx.cursor()

# SQL para insertar datos en la tabla peliculas
sql = "INSERT INTO datos_fase1 (Tipo, Nombre, Año, Mes, id_pelicula, Genero) VALUES (%s, %s, %s, %s, %s, %s)"

# Datos a insertar
val1 = lista_de_tuplas_modificada

val2 = [
    (7.7, 77, "Richard Donner", ["Chris Columbus", "Steven Spielberg"], "Los Goonies son un grupo de amigos que viven en Goon Docks, Astoria, pero sus casas han sido compradas y van a ser demolidas. Sin embargo, vivirán su última aventura en busca de un tesoro que pueda salvar el barrio.", "Aventura", "1h 54min", "Los Goonies"),
    (8.5, 85, "Director 2", ["Guionista 1", "Guionista 2"], "Sinopsis de Otra Pelicula", "Género de Otra Pelicula", "2h 10min", "Otra Pelicula"),
    # Agrega más detalles de películas correspondientes a val1
]

val = []

# Asegurarse de que las listas tengan la misma longitud
min_len = min(len(val1), len(val2))

# Procesar los datos para cada película
for i in range(min_len):
    tipo = val1[i][0]
    titulo = val1[i][1]
    fecha_estreno = val1[i][2]
    id_pelicula = val1[i][3]
    imdb = val2[i][0]
    tomatoes = val2[i][1]
    directores = ','.join(val2[i][2])
    guionistas = ','.join(val2[i][3])
    argumento = val2[i][4]
    genero = val2[i][5]
    duracion = val2[i][6]
    titulo2 = val2[i][7]
    
    val.append((tipo, titulo, fecha_estreno, id_pelicula, imdb, tomatoes, directores, guionistas, argumento, genero, duracion, titulo2))

try:
    mycursor.executemany(sql, val)
    cnx.commit()
    print(mycursor.rowcount, "registro/s insertado/s.")
except mysql.connector.Error as err:
    print("Error: {}".format(err))
finally:
    mycursor.close()
    cnx.close()
